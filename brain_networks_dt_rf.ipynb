# %%
# Drop unnamed columns if present
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

print("Clean columns:", df.columns.tolist())
# Out:
# Clean columns: ['1', '1.1', '2', '2.1', '3', '3.1', '4', '4.1', '5', '5.1', '6', '6.1', '6.2', '6.3', '7', '7.1', '7.2', '7.3', '7.4', '7.5', '8', '8.1', '8.2', '8.3', '8.4', '8.5', '9', '9.1', '10', '10.1', '11', '11.1', '12', '12.1', '12.2', '12.3', '12.4', '13', '13.1', '13.2', '13.3', '13.4', '13.5', '14', '14.1', '15', '15.1', '16', '16.1', '16.2', '16.3', '16.4', '16.5', '16.6', '16.7', '17', '17.1', '17.2', '17.3', '17.4', '17.5', '17.6']

# %%
df = pd.read_csv(
    "Brain Network.csv",
    sep=';',
    engine='python',
    on_bad_lines='skip'
)

# %%
with open("Brain Network.csv", "r") as f:
    for i in range(10):
        print(f.readline())
# Out:
# Brain Networks Dataset Description
#
#
#
# Overview:
#
# The Brain Networks dataset contains numerical and/or categorical data representing
#
# brain connectivity features. These features are typically derived from neuroimaging
#
# techniques such as fMRI and are used to analyze patterns in brain activity.
#
#
#
# Purpose:
#
# The dataset is used for machine learning tasks such as classification or regression,
#
# with the goal of identifying patterns in brain connectivity that may relate to
