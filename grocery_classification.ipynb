# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv("groceries.csv")

df.head()
# Out:
#    Age  Income  FamilySize  ...  OnlineShopper  OrganicPreference  PurchaseCategory
# 0   25   30000           1  ...              1                  0            Snacks
# 1   45   60000           4  ...              0                  1        Vegetables
# 2   35   50000           3  ...              1                  1            Fruits
# 3   23   28000           1  ...              1                  0            Snacks
# 4   52   75000           5  ...              0                  1        Vegetables
#
# [5 rows x 7 columns]

# %%
print(df.head())
# Out:
#    Age  Income  FamilySize  ...  OnlineShopper  OrganicPreference  PurchaseCategory
# 0   25   30000           1  ...              1                  0            Snacks
# 1   45   60000           4  ...              0                  1        Vegetables
# 2   35   50000           3  ...              1                  1            Fruits
# 3   23   28000           1  ...              1                  0            Snacks
# 4   52   75000           5  ...              0                  1        Vegetables
#
# [5 rows x 7 columns]

# %%
print(df.head())
print(df.columns)
# Out:
#    Age  Income  FamilySize  ...  OnlineShopper  OrganicPreference  PurchaseCategory
# 0   25   30000           1  ...              1                  0            Snacks
# 1   45   60000           4  ...              0                  1        Vegetables
# 2   35   50000           3  ...              1                  1            Fruits
# 3   23   28000           1  ...              1                  0            Snacks
# 4   52   75000           5  ...              0                  1        Vegetables
#
# [5 rows x 7 columns]
# Index(['Age', 'Income', 'FamilySize', 'SpendingScore', 'OnlineShopper',
#        'OrganicPreference', 'PurchaseCategory'],
#       dtype='str')

# %%
hasattr(rf_model, "estimators_")
# Out:
# False
